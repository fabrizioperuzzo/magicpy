# %%
# standard library
import os

# dash libs
import dash
from dash.dependencies import Input, Output
import dash_core_components as dcc
import dash_html_components as html
import plotly.figure_factory as ff
import plotly.graph_objs as go

# pydata stack
import pandas as pd

# %% [markdown]
# ### caricamnento da mysql da rivedere

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql://root:T0r1n0$@localhost/databaseprova')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-d0eae8da9488> in <module>
#       1 from sqlalchemy import create_engine
# ----> 2 engine = create_engine('mysql://root:T0r1n0$@localhost/databaseprova')
#
# ~\anaconda3\envs\env4\lib\site-packages\sqlalchemy\engine\__init__.py in create_engine(*args, **kwargs)
#     518     strategy = kwargs.pop("strategy", default_strategy)
#     519     strategy = strategies.strategies[strategy]
# --> 520     return strategy.create(*args, **kwargs)
#     521
#     522
#
# ~\anaconda3\envs\env4\lib\site-packages\sqlalchemy\engine\strategies.py in create(self, name_or_url, **kwargs)
#      85                 if k in kwargs:
#      86                     dbapi_args[k] = pop_kwarg(k)
# ---> 87             dbapi = dialect_cls.dbapi(**dbapi_args)
#      88
#      89         dialect_args["dbapi"] = dbapi
#
# ~\anaconda3\envs\env4\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in dbapi(cls)
#     116     @classmethod
#     117     def dbapi(cls):
# --> 118         return __import__("MySQLdb")
#     119
#     120     def on_connect(self):
#
# ModuleNotFoundError: No module named 'MySQLdb'

# %%
#pip install mysql-connector-python==8.0.21
import mysql.connector

miodb = mysql.connector.connect(
    host='localhost',
    user='root',
    password='T0r1n0$',
    database='databaseprova'
)
# Out:
# ---------------------------------------------------------------------------
# NotSupportedError                         Traceback (most recent call last)
# <ipython-input-16-c399edece72a> in <module>
#       2 import mysql.connector
#       3
# ----> 4 miodb = mysql.connector.connect(
#       5     host='localhost',
#       6     user='root',
#
# ~\anaconda3\envs\env4\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     177         for _ in range(len(failover_list)):
#     178             last = len(failover_list) - 1
# --> 179             index = random.randint(0, last)
#     180             server = failover_list.pop(index)
#     181             new_config = config.copy()
#
# ~\anaconda3\envs\env4\lib\site-packages\mysql\connector\connection.py in __init__(self, *args, **kwargs)
#      93         self._have_next_result = False
#      94         self._raw = False
# ---> 95         self._in_transaction = False
#      96
#      97         self._prepared_statements = None
#
# ~\anaconda3\envs\env4\lib\site-packages\mysql\connector\abstracts.py in connect(self, **kwargs)
#     714             raise errors.ProgrammingError(
#     715                 "set_client_flags expect integer (>0) or set")
# --> 716         return self._client_flags
#     717
#     718     def isset_client_flag(self, flag):
#
# ~\anaconda3\envs\env4\lib\site-packages\mysql\connector\connection.py in _open_connection(self)
#     206                                        ssl_options.get('verify_identity') or
#     207                                        False,
# --> 208                                        tls_ciphersuites,
#     209                                        ssl_options.get('tls_versions'))
#     210             self._ssl_active = True
#
# ~\anaconda3\envs\env4\lib\site-packages\mysql\connector\connection.py in _do_auth(self, username, password, database, client_flags, charset, ssl_options)
#     135         else:
#     136             client_license = "Commercial"
# --> 137         default_conn_attrs = {
#     138             "_pid": str(os.getpid()),
#     139             "_platform": platform_arch,
#
# ~\anaconda3\envs\env4\lib\site-packages\mysql\connector\protocol.py in make_auth(self, handshake, username, password, database, charset, client_flags, max_allowed_packet, ssl_enabled, auth_plugin)
#      97             username_bytes = username.encode('utf8')  # pylint: disable=E1103
#      98         except AttributeError:
# ---> 99             # Username is already bytes
#     100             username_bytes = username
#     101         packet = struct.pack('<IIH{filler}{usrlen}sx'.format(
#
# ~\anaconda3\envs\env4\lib\site-packages\mysql\connector\protocol.py in _auth_response(self, client_flags, username, password, database, auth_plugin, auth_data, ssl_enabled)
#      56         return b'\x00'
#      57
# ---> 58     def _auth_response(self, client_flags, username, password, database,
#      59                        auth_plugin, auth_data, ssl_enabled):
#      60         """Prepare the authentication response"""
#
# ~\anaconda3\envs\env4\lib\site-packages\mysql\connector\authentication.py in get_auth_plugin(plugin_name)
#     188         if PY2:
#     189             if isinstance(password, unicode):  # pylint: disable=E0602
# --> 190                 password = password.encode('utf8')
#     191         elif isinstance(password, str):
#     192             password = password.encode('utf8')
#
# NotSupportedError: Authentication plugin 'caching_sha2_password' is not supported

# %%
# standard library
import os

# dash libs
import dash
from dash.dependencies import Input, Output
import dash_core_components as dcc
import dash_html_components as html
import plotly.figure_factory as ff
import plotly.graph_objs as go

# pydata stack
import pandas as pd
from sqlalchemy import create_engine

# set params
conn = create_engine(os.environ['DB_URI'])


###########################
# Data Manipulation / Model
###########################

def fetch_data(q):
    result = pd.read_sql(
        sql=q,
        con=conn
    )
    return result


def get_divisions():
    '''Returns the list of divisions that are stored in the database'''

    division_query = (
        f'''
        SELECT DISTINCT division
        FROM results
        '''
    )
    divisions = fetch_data(division_query)
    divisions = list(divisions['division'].sort_values(ascending=True))
    return divisions


def get_seasons(division):
    '''Returns the seasons of the datbase store'''

    seasons_query = (
        f'''
        SELECT DISTINCT season
        FROM results
        WHERE division='{division}'
        '''
    )
    seasons = fetch_data(seasons_query)
    seasons = list(seasons['season'].sort_values(ascending=False))
    return seasons


def get_teams(division, season):
    '''Returns all teams playing in the division in the season'''

    teams_query = (
        f'''
        SELECT DISTINCT team
        FROM results
        WHERE division='{division}'
        AND season='{season}'
        '''
    )
    teams = fetch_data(teams_query)
    teams = list(teams['team'].sort_values(ascending=True))
    return teams


def get_match_results(division, season, team):
    '''Returns match results for the selected prompts'''

    results_query = (
        f'''
        SELECT date, team, opponent, goals, goals_opp, result, points
        FROM results
        WHERE division='{division}'
        AND season='{season}'
        AND team='{team}'
        ORDER BY date ASC
        '''
    )
    match_results = fetch_data(results_query)
    return match_results


def calculate_season_summary(results):
    record = results.groupby(by=['result'])['team'].count()
    summary = pd.DataFrame(
        data={
            'W': record['W'],
            'L': record['L'],
            'D': record['D'],
            'Points': results['points'].sum()
        },
        columns=['W', 'D', 'L', 'Points'],
        index=results['team'].unique(),
    )
    return summary


def draw_season_points_graph(results):
    dates = results['date']
    points = results['points'].cumsum()

    figure = go.Figure(
        data=[
            go.Scatter(x=dates, y=points, mode='lines+markers')
        ],
        layout=go.Layout(
            title='Points Accumulation',
            showlegend=False
        )
    )

    return figure


#########################
# Dashboard Layout / View
#########################

def generate_table(dataframe, max_rows=10):
    '''Given dataframe, return template generated using Dash components
    '''
    return html.Table(
        # Header
        [html.Tr([html.Th(col) for col in dataframe.columns])] +

        # Body
        [html.Tr([
            html.Td(dataframe.iloc[i][col]) for col in dataframe.columns
        ]) for i in range(min(len(dataframe), max_rows))]
    )


def onLoad_division_options():
    '''Actions to perform upon initial page load'''

    division_options = (
        [{'label': division, 'value': division}
         for division in get_divisions()]
    )
    return division_options


# Set up Dashboard and create layout
app = dash.Dash()
app.css.append_css({
    "external_url": "https://codepen.io/chriddyp/pen/bWLwgP.css"
})

app.layout = html.Div([

    # Page Header
    html.Div([
        html.H1('Soccer Results Viewer')
    ]),

    # Dropdown Grid
    html.Div([
        html.Div([
            # Select Division Dropdown
            html.Div([
                html.Div('Select Division', className='three columns'),
                html.Div(dcc.Dropdown(id='division-selector',
                                      options=onLoad_division_options()),
                         className='nine columns')
            ]),

            # Select Season Dropdown
            html.Div([
                html.Div('Select Season', className='three columns'),
                html.Div(dcc.Dropdown(id='season-selector'),
                         className='nine columns')
            ]),

            # Select Team Dropdown
            html.Div([
                html.Div('Select Team', className='three columns'),
                html.Div(dcc.Dropdown(id='team-selector'),
                         className='nine columns')
            ]),
        ], className='six columns'),

        # Empty
        html.Div(className='six columns'),
    ], className='twleve columns'),

    # Match Results Grid
    html.Div([

        # Match Results Table
        html.Div(
            html.Table(id='match-results'),
            className='six columns'
        ),

        # Season Summary Table and Graph
        html.Div([
            # summary table
            dcc.Graph(id='season-summary'),

            # graph
            dcc.Graph(id='season-graph')
            # style={},

        ], className='six columns')
    ]),
])


#############################################
# Interaction Between Components / Controller
#############################################

# Load Seasons in Dropdown
@app.callback(
    Output(component_id='season-selector', component_property='options'),
    [
        Input(component_id='division-selector', component_property='value')
    ]
)
def populate_season_selector(division):
    seasons = get_seasons(division)
    return [
        {'label': season, 'value': season}
        for season in seasons
    ]


# Load Teams into dropdown
@app.callback(
    Output(component_id='team-selector', component_property='options'),
    [
        Input(component_id='division-selector', component_property='value'),
        Input(component_id='season-selector', component_property='value')
    ]
)
def populate_team_selector(division, season):
    teams = get_teams(division, season)
    return [
        {'label': team, 'value': team}
        for team in teams
    ]


# Load Match results
@app.callback(
    Output(component_id='match-results', component_property='children'),
    [
        Input(component_id='division-selector', component_property='value'),
        Input(component_id='season-selector', component_property='value'),
        Input(component_id='team-selector', component_property='value')
    ]
)
def load_match_results(division, season, team):
    results = get_match_results(division, season, team)
    return generate_table(results, max_rows=50)


# Update Season Summary Table
@app.callback(
    Output(component_id='season-summary', component_property='figure'),
    [
        Input(component_id='division-selector', component_property='value'),
        Input(component_id='season-selector', component_property='value'),
        Input(component_id='team-selector', component_property='value')
    ]
)
def load_season_summary(division, season, team):
    results = get_match_results(division, season, team)

    table = []
    if len(results) > 0:
        summary = calculate_season_summary(results)
        table = ff.create_table(summary)

    return table


# Update Season Point Graph
@app.callback(
    Output(component_id='season-graph', component_property='figure'),
    [
        Input(component_id='division-selector', component_property='value'),
        Input(component_id='season-selector', component_property='value'),
        Input(component_id='team-selector', component_property='value')
    ]
)
def load_season_points_graph(division, season, team):
    results = get_match_results(division, season, team)

    figure = []
    if len(results) > 0:
        figure = draw_season_points_graph(results)

    return figure


# start Flask server
if __name__ == '__main__':
    app.run_server(
        debug=True,
        host='0.0.0.0',
        port=8050
    )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-c61e04ccdf17> in <module>
#      15
#      16 # set params
# ---> 17 conn = create_engine(os.environ['DB_URI'])
#      18
#      19
#
# ~\anaconda3\envs\env4\lib\os.py in __getitem__(self, key)
#     673         except KeyError:
#     674             # raise KeyError with the original key value
# --> 675             raise KeyError(key) from None
#     676         return self.decodevalue(value)
#     677
#
# KeyError: 'DB_URI'

# %% [markdown]
# ### Graph - explora file or drag and drop

# %%
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

colors = {
    "graphBackground": "#F5F5F5",
    "background": "#ffffff",
    "text": "#000000"
}

app.layout = html.Div([
    dcc.Upload(
        id='upload-data',
        children=html.Div([
            'Drag and Drop or ',
            html.A('Select Files')
        ]),
        style={
            'width': '100%',
            'height': '60px',
            'lineHeight': '60px',
            'borderWidth': '1px',
            'borderStyle': 'dashed',
            'borderRadius': '5px',
            'textAlign': 'center',
            'margin': '10px'
        },
        # Allow multiple files to be uploaded
        multiple=True
    ),
    dcc.Graph(id='Mygraph'),
    html.Div(id='output-data-upload')
])


if __name__ == '__main__':
    app.run_server(debug=True, use_reloader=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on

# %% [markdown]
# ### Best Dash

# %%
df = pd.read_csv('../Z-F-Y-S/DB-COM//2021-02-06stock_twits.csv', sep=';')

# %%
df
# Out:
#      Unnamed: 0   index             dateTime                     industry  \
# 0             0    AAPL  2021-02-05 21:00:00  TelecommunicationsEquipment
# 1             0    ABBV  2021-02-05 21:00:00         PharmaceuticalsMajor
# 2             0     ABG  2021-02-05 21:00:00              SpecialtyStores
# 3             0     ABT  2021-02-05 21:00:00           MedicalSpecialties
# 4             0  ACA.PA                    0                            0
# ..          ...     ...                  ...                          ...
# 206           0     XOM  2021-02-05 21:00:00                IntegratedOil
# 207           0       Y  2021-02-05 21:00:00  PropertyOrCasualtyInsurance
# 208           0      ZS  2021-02-05 21:00:00             PackagedSoftware
# 209           0     ZTS  2021-02-05 21:00:00       PharmaceuticalsGeneric
# 210           0    ZYNE  2021-02-05 21:00:00         PharmaceuticalsOther
#
#      volumechange  sentimentchange wk52_high mkt_Cap_bill
# 0          -15.93             1.26    145.09        2.30t
# 1           -0.78             0.00    113.41      191.96b
# 2           60.00             0.00   172.315        2.99b
# 3          -12.18             1.25  124.8200      219.83b
# 4            0.00             0.00         0            0
# ..            ...              ...       ...          ...
# 206          5.73             1.12     61.53      211.44b
# 207          0.00             0.00  847.9450        8.60b
# 208          6.85             0.00       224       29.09b
# 209        -12.20             0.00    176.64       75.70b
# 210         11.27             0.19      7.45      149.55m
#
# [211 rows x 8 columns]

# %%
import dash
from dash.dependencies import Input, Output
import dash_table
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd

# df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/gapminder2007.csv')
df = pd.read_csv('../Z-F-Y-S/DB-COM//2021-02-06stock_twits.csv', sep=';')

app = dash.Dash(__name__)

app.layout = html.Div([
    dash_table.DataTable(
        id='datatable-interactivity',
        columns=[
            {"name": i, "id": i, "deletable": False, "selectable": True} for i in df.columns
        ],
        data=df.to_dict('records'),
        editable=True,
        filter_action="native",
        sort_action="native",
        sort_mode="multi",
        column_selectable="single",
        row_selectable="multi",
        row_deletable=False,
        selected_columns=[],
        selected_rows=[],
        page_action="native",
        page_current= 0,
        page_size= 10,
        style_table={'overflowX': 'auto'},
    ),
    html.Div(id='datatable-interactivity-container')
])

@app.callback(
    Output('datatable-interactivity', 'style_data_conditional'),
    Input('datatable-interactivity', 'selected_columns')
)
def update_styles(selected_columns):
    return [{
        'if': { 'column_id': i },
        'background_color': '#D2F3FF'
    } for i in selected_columns]

@app.callback(
    Output('datatable-interactivity-container', "children"),
    Input('datatable-interactivity', "derived_virtual_data"),
    Input('datatable-interactivity', "derived_virtual_selected_rows"))
def update_graphs(rows, derived_virtual_selected_rows):
    # When the table is first rendered, `derived_virtual_data` and
    # `derived_virtual_selected_rows` will be `None`. This is due to an
    # idiosyncrasy in Dash (unsupplied properties are always None and Dash
    # calls the dependent callbacks when the component is first rendered).
    # So, if `rows` is `None`, then the component was just rendered
    # and its value will be the same as the component's dataframe.
    # Instead of setting `None` in here, you could also set
    # `derived_virtual_data=df.to_rows('dict')` when you initialize
    # the component.
    if derived_virtual_selected_rows is None:
        derived_virtual_selected_rows = []

    dff = df if rows is None else pd.DataFrame(rows)

    colors = ['#7FDBFF' if i in derived_virtual_selected_rows else '#0074D9'
              for i in range(len(dff))]

    return [
        dcc.Graph(
            id=column,
            figure={
                "data": [
                    {
                        "x": dff["index"],
                        "y": dff[column],
                        "type": "bar",
                        "marker": {"color": colors},
                    }
                ],
                "layout": {
                    "xaxis": {"automargin": True},
                    "yaxis": {
                        "automargin": True,
                        "title": {"text": column}
                    },
                    "height": 250,
                    "margin": {"t": 20, "l": 10, "r": 10},
                },
            },
        )
        # check if column exists - user may have deleted it
        # If `column.deletable=False`, then you don't
        # need to do this check.
        for column in ["volumechange","sentimentchange", "wk52_high", "mkt_Cap_bill"] if column in dff
    ]


if __name__ == '__main__':
    app.run_server(debug=True, use_reloader=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on

# %% [markdown]
# ### Prove

# %%
import pandas as pd
df = pd.read_csv('../Z-F-Y-S/DB-COM//2021-02-06stock_twits.csv', sep=';')

# %%
columns=[
            {"name": i, "id": i, "deletable": True, "selectable": True} for i in df.columns
        ]

# %%
columns
# Out:
# [{'name': 'Unnamed: 0',
#   'id': 'Unnamed: 0',
#   'deletable': True,
#   'selectable': True},
#  {'name': 'index', 'id': 'index', 'deletable': True, 'selectable': True},
#  {'name': 'dateTime', 'id': 'dateTime', 'deletable': True, 'selectable': True},
#  {'name': 'industry', 'id': 'industry', 'deletable': True, 'selectable': True},
#  {'name': 'volumechange',
#   'id': 'volumechange',
#   'deletable': True,
#   'selectable': True},
#  {'name': 'sentimentchange',
#   'id': 'sentimentchange',
#   'deletable': True,
#   'selectable': True},
#  {'name': 'wk52_high',
#   'id': 'wk52_high',
#   'deletable': True,
#   'selectable': True},
#  {'name': 'mkt_Cap_bill',
#   'id': 'mkt_Cap_bill',
#   'deletable': True,
#   'selectable': True}]

# %%
data=df.to_dict('records')
data
# Out:
# [{'Unnamed: 0': 0,
#   'index': 'AAPL',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'TelecommunicationsEquipment',
#   'volumechange': -15.93,
#   'sentimentchange': 1.26,
#   'wk52_high': '145.09',
#   'mkt_Cap_bill': '2.30t'},
#  {'Unnamed: 0': 0,
#   'index': 'ABBV',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PharmaceuticalsMajor',
#   'volumechange': -0.78,
#   'sentimentchange': 0.0,
#   'wk52_high': '113.41',
#   'mkt_Cap_bill': '191.96b'},
#  {'Unnamed: 0': 0,
#   'index': 'ABG',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'SpecialtyStores',
#   'volumechange': 60.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '172.315',
#   'mkt_Cap_bill': '2.99b'},
#  {'Unnamed: 0': 0,
#   'index': 'ABT',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'MedicalSpecialties',
#   'volumechange': -12.18,
#   'sentimentchange': 1.25,
#   'wk52_high': '124.8200',
#   'mkt_Cap_bill': '219.83b'},
#  {'Unnamed: 0': 0,
#   'index': 'ACA.PA',
#   'dateTime': '0',
#   'industry': '0',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '0',
#   'mkt_Cap_bill': '0'},
#  {'Unnamed: 0': 0,
#   'index': 'ACB',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'AgriculturalCommoditiesOrMilling',
#   'volumechange': -3.31,
#   'sentimentchange': 0.21,
#   'wk52_high': '21.4800',
#   'mkt_Cap_bill': '2.36b'},
#  {'Unnamed: 0': 0,
#   'index': 'ADS',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'DataProcessingServices',
#   'volumechange': 8.33,
#   'sentimentchange': 0.0,
#   'wk52_high': '107',
#   'mkt_Cap_bill': '4.05b'},
#  {'Unnamed: 0': 0,
#   'index': 'ADS.DE',
#   'dateTime': '0',
#   'industry': '0',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '0',
#   'mkt_Cap_bill': '0'},
#  {'Unnamed: 0': 0,
#   'index': 'AEE',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ElectricUtilities',
#   'volumechange': 7.69,
#   'sentimentchange': 0.0,
#   'wk52_high': '87.655',
#   'mkt_Cap_bill': '18.34b'},
#  {'Unnamed: 0': 0,
#   'index': 'AKBA',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Biotechnology',
#   'volumechange': 20.79,
#   'sentimentchange': 0.16,
#   'wk52_high': '13.71',
#   'mkt_Cap_bill': '651.87m'},
#  {'Unnamed: 0': 0,
#   'index': 'AKSO.OL',
#   'dateTime': '0',
#   'industry': '0',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '0',
#   'mkt_Cap_bill': '0'},
#  {'Unnamed: 0': 0,
#   'index': 'AMD',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Semiconductors',
#   'volumechange': -11.01,
#   'sentimentchange': -0.15,
#   'wk52_high': '99.23',
#   'mkt_Cap_bill': '106.47b'},
#  {'Unnamed: 0': 0,
#   'index': 'AMGN',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Biotechnology',
#   'volumechange': -1.76,
#   'sentimentchange': -0.56,
#   'wk52_high': '276.69',
#   'mkt_Cap_bill': '136.59b'},
#  {'Unnamed: 0': 0,
#   'index': 'AMZ',
#   'dateTime': '0',
#   'industry': '0',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': 'None',
#   'mkt_Cap_bill': '0'},
#  {'Unnamed: 0': 0,
#   'index': 'AMZN',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InternetRetail',
#   'volumechange': 0.42,
#   'sentimentchange': -0.16,
#   'wk52_high': '3552.25',
#   'mkt_Cap_bill': '1.69t'},
#  {'Unnamed: 0': 0,
#   'index': 'ANDE',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'AgriculturalCommoditiesOrMilling',
#   'volumechange': 25.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '26.22',
#   'mkt_Cap_bill': '851.50m'},
#  {'Unnamed: 0': 0,
#   'index': 'ANF',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ApparelOrFootwearRetail',
#   'volumechange': 8.57,
#   'sentimentchange': 0.0,
#   'wk52_high': '26.3',
#   'mkt_Cap_bill': '1.62b'},
#  {'Unnamed: 0': 0,
#   'index': 'APA',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'OilAndGasProduction',
#   'volumechange': -12.37,
#   'sentimentchange': 0.0,
#   'wk52_high': '29.2100',
#   'mkt_Cap_bill': '6.12b'},
#  {'Unnamed: 0': 0,
#   'index': 'APRN',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InternetRetail',
#   'volumechange': -11.2,
#   'sentimentchange': -0.25,
#   'wk52_high': '28.8400',
#   'mkt_Cap_bill': '173.50m'},
#  {'Unnamed: 0': 0,
#   'index': 'ASLN',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Biotechnology',
#   'volumechange': 10.17,
#   'sentimentchange': 0.0,
#   'wk52_high': '3.44',
#   'mkt_Cap_bill': '113.97m'},
#  {'Unnamed: 0': 0,
#   'index': 'AVAV',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'AerospaceAndDefense',
#   'volumechange': 3.85,
#   'sentimentchange': 0.0,
#   'wk52_high': '143.715',
#   'mkt_Cap_bill': '2.96b'},
#  {'Unnamed: 0': 0,
#   'index': 'AZN',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PharmaceuticalsMajor',
#   'volumechange': -7.95,
#   'sentimentchange': 2.15,
#   'wk52_high': '64.94',
#   'mkt_Cap_bill': '130.56b'},
#  {'Unnamed: 0': 0,
#   'index': 'BA',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': '0',
#   'volumechange': -4.17,
#   'sentimentchange': 1.82,
#   'wk52_high': '349.95',
#   'mkt_Cap_bill': '121.22b'},
#  {'Unnamed: 0': 0,
#   'index': 'BAS.DE',
#   'dateTime': '0',
#   'industry': '0',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '0',
#   'mkt_Cap_bill': '0'},
#  {'Unnamed: 0': 0,
#   'index': 'BAYN',
#   'dateTime': '2020-07-21 18:07:16',
#   'industry': 'RegionalBanks',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': 'None',
#   'mkt_Cap_bill': '0'},
#  {'Unnamed: 0': 0,
#   'index': 'BAYN.DE',
#   'dateTime': '0',
#   'industry': '0',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '0',
#   'mkt_Cap_bill': '0'},
#  {'Unnamed: 0': 0,
#   'index': 'BHC',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PharmaceuticalsOther',
#   'volumechange': 8.76,
#   'sentimentchange': 0.0,
#   'wk52_high': '28.8341',
#   'mkt_Cap_bill': '9.99b'},
#  {'Unnamed: 0': 0,
#   'index': 'BIDU',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InternetSoftwareOrServices',
#   'volumechange': 12.23,
#   'sentimentchange': -0.34,
#   'wk52_high': '271.5341',
#   'mkt_Cap_bill': '73.65b'},
#  {'Unnamed: 0': 0,
#   'index': 'BIG',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'DiscountStores',
#   'volumechange': -14.63,
#   'sentimentchange': 0.0,
#   'wk52_high': '67',
#   'mkt_Cap_bill': '2.06b'},
#  {'Unnamed: 0': 0,
#   'index': 'BIIB',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Biotechnology',
#   'volumechange': -14.02,
#   'sentimentchange': -1.97,
#   'wk52_high': '363.9200',
#   'mkt_Cap_bill': '40.38b'},
#  {'Unnamed: 0': 0,
#   'index': 'BMRN',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Biotechnology',
#   'volumechange': -5.26,
#   'sentimentchange': 0.0,
#   'wk52_high': '131.945',
#   'mkt_Cap_bill': '15.47b'},
#  {'Unnamed: 0': 0,
#   'index': 'BMY',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PharmaceuticalsMajor',
#   'volumechange': 17.18,
#   'sentimentchange': 0.03,
#   'wk52_high': '67.55',
#   'mkt_Cap_bill': '137.66b'},
#  {'Unnamed: 0': 0,
#   'index': 'BSX',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'MedicalSpecialties',
#   'volumechange': 2.48,
#   'sentimentchange': 11.34,
#   'wk52_high': '43.44',
#   'mkt_Cap_bill': '55.79b'},
#  {'Unnamed: 0': 0,
#   'index': 'BX',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InvestmentManagers',
#   'volumechange': -2.9,
#   'sentimentchange': 0.0,
#   'wk52_high': '71.5000',
#   'mkt_Cap_bill': '83.59b'},
#  {'Unnamed: 0': 0,
#   'index': 'BYND',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'FoodMajorDiversified',
#   'volumechange': -3.64,
#   'sentimentchange': 1.86,
#   'wk52_high': '221',
#   'mkt_Cap_bill': '10.58b'},
#  {'Unnamed: 0': 0,
#   'index': 'CDW',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InformationTechnologyServices',
#   'volumechange': 6.9,
#   'sentimentchange': -11.11,
#   'wk52_high': '151.2729',
#   'mkt_Cap_bill': '21.59b'},
#  {'Unnamed: 0': 0,
#   'index': 'CGC',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'AgriculturalCommoditiesOrMilling',
#   'volumechange': 1.75,
#   'sentimentchange': 0.27,
#   'wk52_high': '45.4',
#   'mkt_Cap_bill': '16.04b'},
#  {'Unnamed: 0': 0,
#   'index': 'CHWY',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InternetRetail',
#   'volumechange': 0.0,
#   'sentimentchange': 1.89,
#   'wk52_high': '115.2735',
#   'mkt_Cap_bill': '45.68b'},
#  {'Unnamed: 0': 0,
#   'index': 'CIEN',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'TelecommunicationsEquipment',
#   'volumechange': -8.33,
#   'sentimentchange': 0.0,
#   'wk52_high': '61.5150',
#   'mkt_Cap_bill': '8.55b'},
#  {'Unnamed: 0': 0,
#   'index': 'CLLS',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Biotechnology',
#   'volumechange': 4.65,
#   'sentimentchange': 1.92,
#   'wk52_high': '34.71',
#   'mkt_Cap_bill': '1.13b'},
#  {'Unnamed: 0': 0,
#   'index': 'CLR',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'OilAndGasProduction',
#   'volumechange': -17.16,
#   'sentimentchange': 3.22,
#   'wk52_high': '27.45',
#   'mkt_Cap_bill': '7.67b'},
#  {'Unnamed: 0': 0,
#   'index': 'CMCSA',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'CableOrSatelliteTV',
#   'volumechange': -6.21,
#   'sentimentchange': 1.45,
#   'wk52_high': '52.49',
#   'mkt_Cap_bill': '234.12b'},
#  {'Unnamed: 0': 0,
#   'index': 'CNC',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ManagedHealthCare',
#   'volumechange': 28.13,
#   'sentimentchange': 0.0,
#   'wk52_high': '74.7',
#   'mkt_Cap_bill': '34.14b'},
#  {'Unnamed: 0': 0,
#   'index': 'CODX',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Biotechnology',
#   'volumechange': 1.46,
#   'sentimentchange': -0.15,
#   'wk52_high': '30.99',
#   'mkt_Cap_bill': '436.76m'},
#  {'Unnamed: 0': 0,
#   'index': 'COP',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'OilAndGasProduction',
#   'volumechange': -5.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '61.1500',
#   'mkt_Cap_bill': '60.17b'},
#  {'Unnamed: 0': 0,
#   'index': 'COUP',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PackagedSoftware',
#   'volumechange': 0.0,
#   'sentimentchange': 1.47,
#   'wk52_high': '369.12',
#   'mkt_Cap_bill': '25.33b'},
#  {'Unnamed: 0': 0,
#   'index': 'CRON',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'AgriculturalCommoditiesOrMilling',
#   'volumechange': -2.88,
#   'sentimentchange': -0.4,
#   'wk52_high': '12.77',
#   'mkt_Cap_bill': '4.28b'},
#  {'Unnamed: 0': 0,
#   'index': 'CSCO',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': '0',
#   'volumechange': 18.4,
#   'sentimentchange': 0.22,
#   'wk52_high': '50.28',
#   'mkt_Cap_bill': '202.95b'},
#  {'Unnamed: 0': 0,
#   'index': 'CTAS',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'OtherConsumerServices',
#   'volumechange': -23.81,
#   'sentimentchange': 0.0,
#   'wk52_high': '369.1998',
#   'mkt_Cap_bill': '36.23b'},
#  {'Unnamed: 0': 0,
#   'index': 'CUB',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'AerospaceAndDefense',
#   'volumechange': 9.68,
#   'sentimentchange': 0.0,
#   'wk52_high': '68.1550',
#   'mkt_Cap_bill': '2.01b'},
#  {'Unnamed: 0': 0,
#   'index': 'CVNA',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'SpecialtyStores',
#   'volumechange': 3.94,
#   'sentimentchange': 0.58,
#   'wk52_high': '302.46',
#   'mkt_Cap_bill': '20.34b'},
#  {'Unnamed: 0': 0,
#   'index': 'CVX',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'IntegratedOil',
#   'volumechange': -10.44,
#   'sentimentchange': 4.56,
#   'wk52_high': '112.6',
#   'mkt_Cap_bill': '171.83b'},
#  {'Unnamed: 0': 0,
#   'index': 'CYH',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'HospitalOrNursingManagement',
#   'volumechange': -11.63,
#   'sentimentchange': 0.0,
#   'wk52_high': '11.4500',
#   'mkt_Cap_bill': '1.10b'},
#  {'Unnamed: 0': 0,
#   'index': 'DDS',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'DepartmentStores',
#   'volumechange': -10.64,
#   'sentimentchange': 4.55,
#   'wk52_high': '128.0000',
#   'mkt_Cap_bill': '1.78b'},
#  {'Unnamed: 0': 0,
#   'index': 'DIS',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'CableOrSatelliteTV',
#   'volumechange': 2.56,
#   'sentimentchange': 1.81,
#   'wk52_high': '183.4',
#   'mkt_Cap_bill': '328.67b'},
#  {'Unnamed: 0': 0,
#   'index': 'DLTR',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'DiscountStores',
#   'volumechange': 4.55,
#   'sentimentchange': 0.0,
#   'wk52_high': '115.45',
#   'mkt_Cap_bill': '24.85b'},
#  {'Unnamed: 0': 0,
#   'index': 'DXC',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'DataProcessingServices',
#   'volumechange': 2.65,
#   'sentimentchange': 0.0,
#   'wk52_high': '32.5900',
#   'mkt_Cap_bill': '6.60b'},
#  {'Unnamed: 0': 0,
#   'index': 'EL',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'HouseholdOrPersonalCare',
#   'volumechange': 37.08,
#   'sentimentchange': 0.0,
#   'wk52_high': '276.94',
#   'mkt_Cap_bill': '98.65b'},
#  {'Unnamed: 0': 0,
#   'index': 'EVRG',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ElectricUtilities',
#   'volumechange': -5.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '76.57',
#   'mkt_Cap_bill': '12.45b'},
#  {'Unnamed: 0': 0,
#   'index': 'FB',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InternetSoftwareOrServices',
#   'volumechange': -15.5,
#   'sentimentchange': 2.93,
#   'wk52_high': '304.67',
#   'mkt_Cap_bill': '763.46b'},
#  {'Unnamed: 0': 0,
#   'index': 'FDX',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'AirFreightOrCouriers',
#   'volumechange': -6.67,
#   'sentimentchange': 3.38,
#   'wk52_high': '305.66',
#   'mkt_Cap_bill': '67.60b'},
#  {'Unnamed: 0': 0,
#   'index': 'FE',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ElectricUtilities',
#   'volumechange': 2.17,
#   'sentimentchange': 0.0,
#   'wk52_high': '52.515',
#   'mkt_Cap_bill': '17.51b'},
#  {'Unnamed: 0': 0,
#   'index': 'FIVE',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'DiscountStores',
#   'volumechange': -22.58,
#   'sentimentchange': 0.0,
#   'wk52_high': '197.45',
#   'mkt_Cap_bill': '10.66b'},
#  {'Unnamed: 0': 0,
#   'index': 'FOSL',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'OtherConsumerSpecialties',
#   'volumechange': -21.62,
#   'sentimentchange': 0.0,
#   'wk52_high': '28.5999',
#   'mkt_Cap_bill': '888.44m'},
#  {'Unnamed: 0': 0,
#   'index': 'FSLY',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InformationTechnologyServices',
#   'volumechange': 4.78,
#   'sentimentchange': 0.46,
#   'wk52_high': '136.5',
#   'mkt_Cap_bill': '12.84b'},
#  {'Unnamed: 0': 0,
#   'index': 'FTCH',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': '0',
#   'volumechange': 2.33,
#   'sentimentchange': 0.0,
#   'wk52_high': '69.4525',
#   'mkt_Cap_bill': '22.61b'},
#  {'Unnamed: 0': 0,
#   'index': 'GDX',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InvestmentTrustsOrMutualFunds',
#   'volumechange': -7.85,
#   'sentimentchange': 2.92,
#   'wk52_high': '45.78',
#   'mkt_Cap_bill': '– – –'},
#  {'Unnamed: 0': 0,
#   'index': 'GDXJ',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InvestmentTrustsOrMutualFunds',
#   'volumechange': -3.85,
#   'sentimentchange': -0.67,
#   'wk52_high': '65.9501',
#   'mkt_Cap_bill': '– – –'},
#  {'Unnamed: 0': 0,
#   'index': 'GE',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'FinanceOrRentalOrLeasing',
#   'volumechange': -8.06,
#   'sentimentchange': -1.37,
#   'wk52_high': '13.2600',
#   'mkt_Cap_bill': '99.86b'},
#  {'Unnamed: 0': 0,
#   'index': 'GH',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'MedicalOrNursingServices',
#   'volumechange': 40.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '168.52',
#   'mkt_Cap_bill': '16.25b'},
#  {'Unnamed: 0': 0,
#   'index': 'GILD',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Biotechnology',
#   'volumechange': 7.38,
#   'sentimentchange': 0.63,
#   'wk52_high': '85.97',
#   'mkt_Cap_bill': '85.82b'},
#  {'Unnamed: 0': 0,
#   'index': 'GME',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ElectronicsOrApplianceStores',
#   'volumechange': -13.72,
#   'sentimentchange': -3.78,
#   'wk52_high': '483',
#   'mkt_Cap_bill': '4.45b'},
#  {'Unnamed: 0': 0,
#   'index': 'GOLD',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PreciousMetals',
#   'volumechange': -3.21,
#   'sentimentchange': -0.72,
#   'wk52_high': '31.22',
#   'mkt_Cap_bill': '39.71b'},
#  {'Unnamed: 0': 0,
#   'index': 'GOOGL',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InternetSoftwareOrServices',
#   'volumechange': 2.32,
#   'sentimentchange': 0.43,
#   'wk52_high': '2106.6234',
#   'mkt_Cap_bill': '1.41t'},
#  {'Unnamed: 0': 0,
#   'index': 'GPI',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': '0',
#   'volumechange': -18.92,
#   'sentimentchange': 0.0,
#   'wk52_high': '162.6463',
#   'mkt_Cap_bill': '2.71b'},
#  {'Unnamed: 0': 0,
#   'index': 'GPRO',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ElectronicsOrAppliances',
#   'volumechange': 6.67,
#   'sentimentchange': -1.02,
#   'wk52_high': '11.19',
#   'mkt_Cap_bill': '1.56b'},
#  {'Unnamed: 0': 0,
#   'index': 'GSAT',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'WirelessTelecommunications',
#   'volumechange': 1.78,
#   'sentimentchange': 0.06,
#   'wk52_high': '1.48',
#   'mkt_Cap_bill': '1.95b'},
#  {'Unnamed: 0': 0,
#   'index': 'GSK',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PharmaceuticalsMajor',
#   'volumechange': 3.75,
#   'sentimentchange': 0.0,
#   'wk52_high': '44.6500',
#   'mkt_Cap_bill': '88.05b'},
#  {'Unnamed: 0': 0,
#   'index': 'HCA',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'HospitalOrNursingManagement',
#   'volumechange': 86.3,
#   'sentimentchange': 0.0,
#   'wk52_high': '181.0100',
#   'mkt_Cap_bill': '59.82b'},
#  {'Unnamed: 0': 0,
#   'index': 'HD',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'HomeImprovementChains',
#   'volumechange': 0.59,
#   'sentimentchange': 0.1,
#   'wk52_high': '292.95',
#   'mkt_Cap_bill': '300.22b'},
#  {'Unnamed: 0': 0,
#   'index': 'HES',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'OilAndGasProduction',
#   'volumechange': 8.06,
#   'sentimentchange': 0.0,
#   'wk52_high': '64.98',
#   'mkt_Cap_bill': '17.48b'},
#  {'Unnamed: 0': 0,
#   'index': 'HIBB',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'SpecialtyStores',
#   'volumechange': 25.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '61.13',
#   'mkt_Cap_bill': '994.87m'},
#  {'Unnamed: 0': 0,
#   'index': 'HPQ',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ComputerProcessingHardware',
#   'volumechange': -3.23,
#   'sentimentchange': 0.0,
#   'wk52_high': '26.5800',
#   'mkt_Cap_bill': '33.72b'},
#  {'Unnamed: 0': 0,
#   'index': 'HSBC',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'MajorBanks',
#   'volumechange': -50.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '38.6100',
#   'mkt_Cap_bill': '108.93b'},
#  {'Unnamed: 0': 0,
#   'index': 'IAC',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InternetSoftwareOrServices',
#   'volumechange': 12.77,
#   'sentimentchange': 0.0,
#   'wk52_high': '324.74',
#   'mkt_Cap_bill': '21.21b'},
#  {'Unnamed: 0': 0,
#   'index': 'IBKR',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InvestmentBanksOrBrokers',
#   'volumechange': -14.05,
#   'sentimentchange': 16.67,
#   'wk52_high': '72.5400',
#   'mkt_Cap_bill': '6.53b'},
#  {'Unnamed: 0': 0,
#   'index': 'IBM',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InformationTechnologyServices',
#   'volumechange': -1.5,
#   'sentimentchange': -0.11,
#   'wk52_high': '155.6',
#   'mkt_Cap_bill': '108.52b'},
#  {'Unnamed: 0': 0,
#   'index': 'ICPT',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PharmaceuticalsOther',
#   'volumechange': -1.01,
#   'sentimentchange': -0.11,
#   'wk52_high': '99.6',
#   'mkt_Cap_bill': '1.15b'},
#  {'Unnamed: 0': 0,
#   'index': 'ILMN',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Biotechnology',
#   'volumechange': 1.45,
#   'sentimentchange': 0.1,
#   'wk52_high': '453.68',
#   'mkt_Cap_bill': '62.58b'},
#  {'Unnamed: 0': 0,
#   'index': 'INCY',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Biotechnology',
#   'volumechange': -28.89,
#   'sentimentchange': 0.0,
#   'wk52_high': '110.365',
#   'mkt_Cap_bill': '19.76b'},
#  {'Unnamed: 0': 0,
#   'index': 'INTC',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Semiconductors',
#   'volumechange': -6.88,
#   'sentimentchange': 0.41,
#   'wk52_high': '68.09',
#   'mkt_Cap_bill': '236.33b'},
#  {'Unnamed: 0': 0,
#   'index': 'IPGP',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Semiconductors',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '262.5511',
#   'mkt_Cap_bill': '12.71b'},
#  {'Unnamed: 0': 0,
#   'index': 'ISRG',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'MedicalSpecialties',
#   'volumechange': -1.25,
#   'sentimentchange': 0.0,
#   'wk52_high': '826.81',
#   'mkt_Cap_bill': '89.61b'},
#  {'Unnamed: 0': 0,
#   'index': 'JBL',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ElectronicComponents',
#   'volumechange': -21.43,
#   'sentimentchange': 0.0,
#   'wk52_high': '46.18',
#   'mkt_Cap_bill': '6.71b'},
#  {'Unnamed: 0': 0,
#   'index': 'JFU',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InternetSoftwareOrServices',
#   'volumechange': 20.13,
#   'sentimentchange': 0.51,
#   'wk52_high': '9.99',
#   'mkt_Cap_bill': '220.55m'},
#  {'Unnamed: 0': 0,
#   'index': 'JMP',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InvestmentBanksOrBrokers',
#   'volumechange': 80.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '4.4800',
#   'mkt_Cap_bill': '84.96m'},
#  {'Unnamed: 0': 0,
#   'index': 'JNJ',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PharmaceuticalsMajor',
#   'volumechange': -13.94,
#   'sentimentchange': 2.48,
#   'wk52_high': '173.65',
#   'mkt_Cap_bill': '432.92b'},
#  {'Unnamed: 0': 0,
#   'index': 'JPC',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InvestmentTrustsOrMutualFunds',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '10.765',
#   'mkt_Cap_bill': '– – –'},
#  {'Unnamed: 0': 0,
#   'index': 'JPM',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'MajorBanks',
#   'volumechange': -9.32,
#   'sentimentchange': 1.72,
#   'wk52_high': '142.75',
#   'mkt_Cap_bill': '420.59b'},
#  {'Unnamed: 0': 0,
#   'index': 'JUVE.MI',
#   'dateTime': '0',
#   'industry': '0',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '0',
#   'mkt_Cap_bill': '0'},
#  {'Unnamed: 0': 0,
#   'index': 'KHC',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'FoodMajorDiversified',
#   'volumechange': 3.14,
#   'sentimentchange': -1.4,
#   'wk52_high': '36.3686',
#   'mkt_Cap_bill': '41.32b'},
#  {'Unnamed: 0': 0,
#   'index': 'KLAC',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ElectronicProductionEquipment',
#   'volumechange': 2.27,
#   'sentimentchange': 0.0,
#   'wk52_high': '317.6000',
#   'mkt_Cap_bill': '44.68b'},
#  {'Unnamed: 0': 0,
#   'index': 'KO',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'BeveragesNonAlcoholic',
#   'volumechange': 1.18,
#   'sentimentchange': 0.5,
#   'wk52_high': '60.13',
#   'mkt_Cap_bill': '213.37b'},
#  {'Unnamed: 0': 0,
#   'index': 'KRTX',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PharmaceuticalsMajor',
#   'volumechange': 43.48,
#   'sentimentchange': 0.0,
#   'wk52_high': '123.73',
#   'mkt_Cap_bill': '3.20b'},
#  {'Unnamed: 0': 0,
#   'index': 'KZR',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Biotechnology',
#   'volumechange': 25.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '9.79',
#   'mkt_Cap_bill': '245.22m'},
#  {'Unnamed: 0': 0,
#   'index': 'LLY',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PharmaceuticalsMajor',
#   'volumechange': -10.88,
#   'sentimentchange': 0.36,
#   'wk52_high': '218',
#   'mkt_Cap_bill': '193.01b'},
#  {'Unnamed: 0': 0,
#   'index': 'LRCX',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ElectronicProductionEquipment',
#   'volumechange': 7.14,
#   'sentimentchange': 5.88,
#   'wk52_high': '585.4161',
#   'mkt_Cap_bill': '72.85b'},
#  {'Unnamed: 0': 0,
#   'index': 'LYFT',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PackagedSoftware',
#   'volumechange': 10.4,
#   'sentimentchange': 1.17,
#   'wk52_high': '54.5',
#   'mkt_Cap_bill': '16.87b'},
#  {'Unnamed: 0': 0,
#   'index': 'MAT',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'RecreationalProducts',
#   'volumechange': 5.56,
#   'sentimentchange': 0.0,
#   'wk52_high': '19.42',
#   'mkt_Cap_bill': '6.44b'},
#  {'Unnamed: 0': 0,
#   'index': 'MCD',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Restaurants',
#   'volumechange': -12.08,
#   'sentimentchange': 1.85,
#   'wk52_high': '231.91',
#   'mkt_Cap_bill': '158.40b'},
#  {'Unnamed: 0': 0,
#   'index': 'MDB',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PackagedSoftware',
#   'volumechange': 1.47,
#   'sentimentchange': 0.0,
#   'wk52_high': '419.94',
#   'mkt_Cap_bill': '24.87b'},
#  {'Unnamed: 0': 0,
#   'index': 'MIK',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'SpecialtyStores',
#   'volumechange': -1.61,
#   'sentimentchange': 0.15,
#   'wk52_high': '17.9',
#   'mkt_Cap_bill': '2.38b'},
#  {'Unnamed: 0': 0,
#   'index': 'MKC',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'FoodSpecialtyOrCandy',
#   'volumechange': -12.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '105.535',
#   'mkt_Cap_bill': '24.09b'},
#  {'Unnamed: 0': 0,
#   'index': 'MMM',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'IndustrialConglomerates',
#   'volumechange': -4.39,
#   'sentimentchange': 0.0,
#   'wk52_high': '187.27',
#   'mkt_Cap_bill': '103.42b'},
#  {'Unnamed: 0': 0,
#   'index': 'MO',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Tobacco',
#   'volumechange': -4.84,
#   'sentimentchange': -5.13,
#   'wk52_high': '46.6800',
#   'mkt_Cap_bill': '78.93b'},
#  {'Unnamed: 0': 0,
#   'index': 'MPC',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'OilRefiningOrMarketing',
#   'volumechange': -10.69,
#   'sentimentchange': -0.29,
#   'wk52_high': '60.35',
#   'mkt_Cap_bill': '30.81b'},
#  {'Unnamed: 0': 0,
#   'index': 'MRK',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PharmaceuticalsMajor',
#   'volumechange': 3.51,
#   'sentimentchange': -0.74,
#   'wk52_high': '87.8',
#   'mkt_Cap_bill': '191.78b'},
#  {'Unnamed: 0': 0,
#   'index': 'MRO',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'OilAndGasProduction',
#   'volumechange': 4.34,
#   'sentimentchange': -1.7,
#   'wk52_high': '11.9700',
#   'mkt_Cap_bill': '6.27b'},
#  {'Unnamed: 0': 0,
#   'index': 'MSFT',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PackagedSoftware',
#   'volumechange': -5.38,
#   'sentimentchange': -0.27,
#   'wk52_high': '245.09',
#   'mkt_Cap_bill': '1.83t'},
#  {'Unnamed: 0': 0,
#   'index': 'MTCH',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InternetSoftwareOrServices',
#   'volumechange': 7.33,
#   'sentimentchange': 0.44,
#   'wk52_high': '159.9900',
#   'mkt_Cap_bill': '41.56b'},
#  {'Unnamed: 0': 0,
#   'index': 'MUR',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'OilAndGasProduction',
#   'volumechange': 40.79,
#   'sentimentchange': 25.0,
#   'wk52_high': '22.9800',
#   'mkt_Cap_bill': '2.00b'},
#  {'Unnamed: 0': 0,
#   'index': 'NET',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InformationTechnologyServices',
#   'volumechange': 13.53,
#   'sentimentchange': 0.11,
#   'wk52_high': '88.77',
#   'mkt_Cap_bill': '26.29b'},
#  {'Unnamed: 0': 0,
#   'index': 'NEWR',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InformationTechnologyServices',
#   'volumechange': 24.69,
#   'sentimentchange': 57.14,
#   'wk52_high': '81.1',
#   'mkt_Cap_bill': '4.23b'},
#  {'Unnamed: 0': 0,
#   'index': 'NIO',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'MotorVehicles',
#   'volumechange': -4.24,
#   'sentimentchange': -0.29,
#   'wk52_high': '66.99',
#   'mkt_Cap_bill': '73.24b'},
#  {'Unnamed: 0': 0,
#   'index': 'NKE',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ApparelOrFootwear',
#   'volumechange': 0.89,
#   'sentimentchange': -0.11,
#   'wk52_high': '147.95',
#   'mkt_Cap_bill': '228.76b'},
#  {'Unnamed: 0': 0,
#   'index': 'NOG.L',
#   'dateTime': '0',
#   'industry': '0',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '0',
#   'mkt_Cap_bill': '0'},
#  {'Unnamed: 0': 0,
#   'index': 'NOW',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InformationTechnologyServices',
#   'volumechange': -3.33,
#   'sentimentchange': 2.39,
#   'wk52_high': '592.54',
#   'mkt_Cap_bill': '115.06b'},
#  {'Unnamed: 0': 0,
#   'index': 'NTAP',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ComputerPeripherals',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '70.64',
#   'mkt_Cap_bill': '15.05b'},
#  {'Unnamed: 0': 0,
#   'index': 'NVDA',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Semiconductors',
#   'volumechange': -3.58,
#   'sentimentchange': -0.45,
#   'wk52_high': '589.0699',
#   'mkt_Cap_bill': '336.51b'},
#  {'Unnamed: 0': 0,
#   'index': 'NVO',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PharmaceuticalsMajor',
#   'volumechange': -1.47,
#   'sentimentchange': 0.0,
#   'wk52_high': '73.92',
#   'mkt_Cap_bill': '125.99b'},
#  {'Unnamed: 0': 0,
#   'index': 'NVR',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Homebuilding',
#   'volumechange': -3.57,
#   'sentimentchange': 0.0,
#   'wk52_high': '4693.59',
#   'mkt_Cap_bill': '17.25b'},
#  {'Unnamed: 0': 0,
#   'index': 'NVS',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PharmaceuticalsMajor',
#   'volumechange': 7.5,
#   'sentimentchange': 0.0,
#   'wk52_high': '99.8429',
#   'mkt_Cap_bill': '204.31b'},
#  {'Unnamed: 0': 0,
#   'index': 'OIL',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InvestmentTrustsOrMutualFunds',
#   'volumechange': 10.64,
#   'sentimentchange': 0.0,
#   'wk52_high': '18.34',
#   'mkt_Cap_bill': '– – –'},
#  {'Unnamed: 0': 0,
#   'index': 'OKTA',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PackagedSoftware',
#   'volumechange': -1.35,
#   'sentimentchange': -3.21,
#   'wk52_high': '287.35',
#   'mkt_Cap_bill': '36.62b'},
#  {'Unnamed: 0': 0,
#   'index': 'OMI',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'MedicalDistributors',
#   'volumechange': 26.32,
#   'sentimentchange': 0.0,
#   'wk52_high': '31.9',
#   'mkt_Cap_bill': '2.15b'},
#  {'Unnamed: 0': 0,
#   'index': 'ORCL',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': '0',
#   'volumechange': 2.0,
#   'sentimentchange': 0.3,
#   'wk52_high': '66.2',
#   'mkt_Cap_bill': '187.24b'},
#  {'Unnamed: 0': 0,
#   'index': 'OSTK',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InternetRetail',
#   'volumechange': -2.09,
#   'sentimentchange': 1.99,
#   'wk52_high': '128.5',
#   'mkt_Cap_bill': '3.96b'},
#  {'Unnamed: 0': 0,
#   'index': 'PAM',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ElectricUtilities',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '14.78',
#   'mkt_Cap_bill': '753.10m'},
#  {'Unnamed: 0': 0,
#   'index': 'PBF',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'OilRefiningOrMarketing',
#   'volumechange': -27.07,
#   'sentimentchange': 0.0,
#   'wk52_high': '29.575',
#   'mkt_Cap_bill': '1.14b'},
#  {'Unnamed: 0': 0,
#   'index': 'PBYI',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Biotechnology',
#   'volumechange': -6.15,
#   'sentimentchange': 4.12,
#   'wk52_high': '14.95',
#   'mkt_Cap_bill': '487.49m'},
#  {'Unnamed: 0': 0,
#   'index': 'PCG',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ElectricUtilities',
#   'volumechange': -5.97,
#   'sentimentchange': 14.11,
#   'wk52_high': '18.34',
#   'mkt_Cap_bill': '23.54b'},
#  {'Unnamed: 0': 0,
#   'index': 'PDL.L',
#   'dateTime': '0',
#   'industry': '0',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '0',
#   'mkt_Cap_bill': '0'},
#  {'Unnamed: 0': 0,
#   'index': 'PEP',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'BeveragesNonAlcoholic',
#   'volumechange': -4.3,
#   'sentimentchange': 6.67,
#   'wk52_high': '148.77',
#   'mkt_Cap_bill': '194.80b'},
#  {'Unnamed: 0': 0,
#   'index': 'PFE',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PharmaceuticalsMajor',
#   'volumechange': -8.94,
#   'sentimentchange': 0.97,
#   'wk52_high': '43.0797',
#   'mkt_Cap_bill': '194.10b'},
#  {'Unnamed: 0': 0,
#   'index': 'PG',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'HouseholdOrPersonalCare',
#   'volumechange': 10.08,
#   'sentimentchange': -2.12,
#   'wk52_high': '146.92',
#   'mkt_Cap_bill': '319.06b'},
#  {'Unnamed: 0': 0,
#   'index': 'PHM',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Homebuilding',
#   'volumechange': 34.43,
#   'sentimentchange': 0.0,
#   'wk52_high': '50.23',
#   'mkt_Cap_bill': '12.80b'},
#  {'Unnamed: 0': 0,
#   'index': 'PLTR',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PackagedSoftware',
#   'volumechange': -0.43,
#   'sentimentchange': 0.8,
#   'wk52_high': '45',
#   'mkt_Cap_bill': '59.32b'},
#  {'Unnamed: 0': 0,
#   'index': 'PLUS',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ElectronicsDistributors',
#   'volumechange': 19.23,
#   'sentimentchange': 0.0,
#   'wk52_high': '95.9400',
#   'mkt_Cap_bill': '1.24b'},
#  {'Unnamed: 0': 0,
#   'index': 'PRGO',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PharmaceuticalsOther',
#   'volumechange': -10.0,
#   'sentimentchange': -33.33,
#   'wk52_high': '63.86',
#   'mkt_Cap_bill': '5.88b'},
#  {'Unnamed: 0': 0,
#   'index': 'PYPL',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'DataProcessingServices',
#   'volumechange': 2.51,
#   'sentimentchange': -0.06,
#   'wk52_high': '274.94',
#   'mkt_Cap_bill': '315.70b'},
#  {'Unnamed: 0': 0,
#   'index': 'RAD',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'DrugstoreChains',
#   'volumechange': -15.27,
#   'sentimentchange': 0.14,
#   'wk52_high': '32.48',
#   'mkt_Cap_bill': '1.30b'},
#  {'Unnamed: 0': 0,
#   'index': 'REGN',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Biotechnology',
#   'volumechange': 16.02,
#   'sentimentchange': -1.83,
#   'wk52_high': '664.64',
#   'mkt_Cap_bill': '53.24b'},
#  {'Unnamed: 0': 0,
#   'index': 'RFP',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PulpAndPaper',
#   'volumechange': 36.36,
#   'sentimentchange': 50.0,
#   'wk52_high': '9.0000',
#   'mkt_Cap_bill': '644.12m'},
#  {'Unnamed: 0': 0,
#   'index': 'RIG',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ContractDrilling',
#   'volumechange': 3.29,
#   'sentimentchange': 0.64,
#   'wk52_high': '4.8200',
#   'mkt_Cap_bill': '2.16b'},
#  {'Unnamed: 0': 0,
#   'index': 'RLGY',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'RealEstateDevelopment',
#   'volumechange': -11.39,
#   'sentimentchange': 0.0,
#   'wk52_high': '16.99',
#   'mkt_Cap_bill': '1.92b'},
#  {'Unnamed: 0': 0,
#   'index': 'RNR',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PropertyOrCasualtyInsurance',
#   'volumechange': 220.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '202.68',
#   'mkt_Cap_bill': '8.10b'},
#  {'Unnamed: 0': 0,
#   'index': 'ROG',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ChemicalsSpecialty',
#   'volumechange': -10.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '184.82',
#   'mkt_Cap_bill': '3.21b'},
#  {'Unnamed: 0': 0,
#   'index': 'ROKU',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ElectronicsOrAppliances',
#   'volumechange': 0.78,
#   'sentimentchange': 0.63,
#   'wk52_high': '448.17',
#   'mkt_Cap_bill': '55.84b'},
#  {'Unnamed: 0': 0,
#   'index': 'ROST',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ApparelOrFootwearRetail',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '124.16',
#   'mkt_Cap_bill': '42.27b'},
#  {'Unnamed: 0': 0,
#   'index': 'RPM',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'IndustrialSpecialties',
#   'volumechange': -9.09,
#   'sentimentchange': 0.0,
#   'wk52_high': '98.3500',
#   'mkt_Cap_bill': '11.25b'},
#  {'Unnamed: 0': 0,
#   'index': 'RRD',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'CommercialPrintingOrForms',
#   'volumechange': 13.33,
#   'sentimentchange': 3.33,
#   'wk52_high': '3.1200',
#   'mkt_Cap_bill': '172.79m'},
#  {'Unnamed: 0': 0,
#   'index': 'SAH',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'SpecialtyStores',
#   'volumechange': -40.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '49.21',
#   'mkt_Cap_bill': '1.81b'},
#  {'Unnamed: 0': 0,
#   'index': 'SCHW',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InvestmentBanksOrBrokers',
#   'volumechange': -12.12,
#   'sentimentchange': 11.94,
#   'wk52_high': '62.0400',
#   'mkt_Cap_bill': '99.21b'},
#  {'Unnamed: 0': 0,
#   'index': 'SCO',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InvestmentTrustsOrMutualFunds',
#   'volumechange': 1.92,
#   'sentimentchange': -3.7,
#   'wk52_high': '67.35',
#   'mkt_Cap_bill': '– – –'},
#  {'Unnamed: 0': 0,
#   'index': 'SHOP',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InternetRetail',
#   'volumechange': -0.15,
#   'sentimentchange': -0.21,
#   'wk52_high': '1296.775',
#   'mkt_Cap_bill': '156.99b'},
#  {'Unnamed: 0': 0,
#   'index': 'SIG',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'SpecialtyStores',
#   'volumechange': -14.81,
#   'sentimentchange': 0.0,
#   'wk52_high': '46.35',
#   'mkt_Cap_bill': '2.27b'},
#  {'Unnamed: 0': 0,
#   'index': 'SIRI',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Broadcasting',
#   'volumechange': -3.32,
#   'sentimentchange': 0.89,
#   'wk52_high': '8.1400',
#   'mkt_Cap_bill': '25.27b'},
#  {'Unnamed: 0': 0,
#   'index': 'SLB',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': '0',
#   'volumechange': -2.25,
#   'sentimentchange': 0.0,
#   'wk52_high': '35.375',
#   'mkt_Cap_bill': '34.54b'},
#  {'Unnamed: 0': 0,
#   'index': 'SLV',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InvestmentTrustsOrMutualFunds',
#   'volumechange': -9.35,
#   'sentimentchange': -0.91,
#   'wk52_high': '27.98',
#   'mkt_Cap_bill': '– – –'},
#  {'Unnamed: 0': 0,
#   'index': 'SNY',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PharmaceuticalsMajor',
#   'volumechange': 14.61,
#   'sentimentchange': 0.0,
#   'wk52_high': '55',
#   'mkt_Cap_bill': '121.14b'},
#  {'Unnamed: 0': 0,
#   'index': 'SPOT',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InternetSoftwareOrServices',
#   'volumechange': 10.36,
#   'sentimentchange': 1.88,
#   'wk52_high': '370.95',
#   'mkt_Cap_bill': '57.18b'},
#  {'Unnamed: 0': 0,
#   'index': 'SQQQ',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InvestmentTrustsOrMutualFunds',
#   'volumechange': -15.45,
#   'sentimentchange': -4.24,
#   'wk52_high': '162.15',
#   'mkt_Cap_bill': '– – –'},
#  {'Unnamed: 0': 0,
#   'index': 'SRPT',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Biotechnology',
#   'volumechange': -13.8,
#   'sentimentchange': -0.75,
#   'wk52_high': '181.8300',
#   'mkt_Cap_bill': '7.56b'},
#  {'Unnamed: 0': 0,
#   'index': 'SWN',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'OilAndGasProduction',
#   'volumechange': -1.38,
#   'sentimentchange': -2.09,
#   'wk52_high': '4.25',
#   'mkt_Cap_bill': '2.24b'},
#  {'Unnamed: 0': 0,
#   'index': 'SYK',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'MedicalSpecialties',
#   'volumechange': 46.15,
#   'sentimentchange': 0.0,
#   'wk52_high': '247.4400',
#   'mkt_Cap_bill': '89.73b'},
#  {'Unnamed: 0': 0,
#   'index': 'SYNA',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Semiconductors',
#   'volumechange': 22.77,
#   'sentimentchange': -8.33,
#   'wk52_high': '125.88',
#   'mkt_Cap_bill': '4.11b'},
#  {'Unnamed: 0': 0,
#   'index': 'SYY',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'FoodDistributors',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '79.96',
#   'mkt_Cap_bill': '39.34b'},
#  {'Unnamed: 0': 0,
#   'index': 'T',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'MajorTelecommunications',
#   'volumechange': -2.92,
#   'sentimentchange': 2.62,
#   'wk52_high': '38.8200',
#   'mkt_Cap_bill': '206.16b'},
#  {'Unnamed: 0': 0,
#   'index': 'TA',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'OtherConsumerServices',
#   'volumechange': 33.33,
#   'sentimentchange': 0.0,
#   'wk52_high': '35.99',
#   'mkt_Cap_bill': '460.22m'},
#  {'Unnamed: 0': 0,
#   'index': 'TEO',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'MajorTelecommunications',
#   'volumechange': -10.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '12.35',
#   'mkt_Cap_bill': '822.76m'},
#  {'Unnamed: 0': 0,
#   'index': 'TEVA',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PharmaceuticalsGeneric',
#   'volumechange': -5.77,
#   'sentimentchange': 3.33,
#   'wk52_high': '13.76',
#   'mkt_Cap_bill': '13.41b'},
#  {'Unnamed: 0': 0,
#   'index': 'THC',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'HospitalOrNursingManagement',
#   'volumechange': 14.29,
#   'sentimentchange': 0.0,
#   'wk52_high': '51.97',
#   'mkt_Cap_bill': '5.34b'},
#  {'Unnamed: 0': 0,
#   'index': 'THG',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PropertyOrCasualtyInsurance',
#   'volumechange': -8.7,
#   'sentimentchange': 0.0,
#   'wk52_high': '139.4000',
#   'mkt_Cap_bill': '4.23b'},
#  {'Unnamed: 0': 0,
#   'index': 'TPR',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ApparelOrFootwearRetail',
#   'volumechange': 4.27,
#   'sentimentchange': 0.0,
#   'wk52_high': '37.76',
#   'mkt_Cap_bill': '10.42b'},
#  {'Unnamed: 0': 0,
#   'index': 'TTM',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'MotorVehicles',
#   'volumechange': 3.92,
#   'sentimentchange': -7.69,
#   'wk52_high': '22.7500',
#   'mkt_Cap_bill': '13.78b'},
#  {'Unnamed: 0': 0,
#   'index': 'TXN',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Semiconductors',
#   'volumechange': 10.98,
#   'sentimentchange': -6.29,
#   'wk52_high': '175.7',
#   'mkt_Cap_bill': '155.99b'},
#  {'Unnamed: 0': 0,
#   'index': 'TYO',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InvestmentTrustsOrMutualFunds',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '10.3397',
#   'mkt_Cap_bill': '– – –'},
#  {'Unnamed: 0': 0,
#   'index': 'UA',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'ApparelOrFootwear',
#   'volumechange': 2.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '18.52',
#   'mkt_Cap_bill': '7.89b'},
#  {'Unnamed: 0': 0,
#   'index': 'UBER',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PackagedSoftware',
#   'volumechange': 4.02,
#   'sentimentchange': 1.24,
#   'wk52_high': '60.03',
#   'mkt_Cap_bill': '108.45b'},
#  {'Unnamed: 0': 0,
#   'index': 'UGA',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InvestmentTrustsOrMutualFunds',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '31.25',
#   'mkt_Cap_bill': '– – –'},
#  {'Unnamed: 0': 0,
#   'index': 'ULTA',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'SpecialtyStores',
#   'volumechange': 10.81,
#   'sentimentchange': 1.82,
#   'wk52_high': '310.4875',
#   'mkt_Cap_bill': '17.02b'},
#  {'Unnamed: 0': 0,
#   'index': 'UNH',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': '0',
#   'volumechange': 16.95,
#   'sentimentchange': -3.47,
#   'wk52_high': '367.95',
#   'mkt_Cap_bill': '307.90b'},
#  {'Unnamed: 0': 0,
#   'index': 'UNP',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Railroads',
#   'volumechange': 71.43,
#   'sentimentchange': 0.0,
#   'wk52_high': '221.28',
#   'mkt_Cap_bill': '137.60b'},
#  {'Unnamed: 0': 0,
#   'index': 'USO',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InvestmentTrustsOrMutualFunds',
#   'volumechange': 4.47,
#   'sentimentchange': 3.29,
#   'wk52_high': '91.4',
#   'mkt_Cap_bill': '– – –'},
#  {'Unnamed: 0': 0,
#   'index': 'V',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'FinanceOrRentalOrLeasing',
#   'volumechange': -15.86,
#   'sentimentchange': 1.08,
#   'wk52_high': '220.39',
#   'mkt_Cap_bill': '446.20b'},
#  {'Unnamed: 0': 0,
#   'index': 'VEON',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'WirelessTelecommunications',
#   'volumechange': 0.0,
#   'sentimentchange': 3.33,
#   'wk52_high': '2.7800',
#   'mkt_Cap_bill': '2.94b'},
#  {'Unnamed: 0': 0,
#   'index': 'VRTX',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Biotechnology',
#   'volumechange': 14.12,
#   'sentimentchange': 0.85,
#   'wk52_high': '306.08',
#   'mkt_Cap_bill': '55.94b'},
#  {'Unnamed: 0': 0,
#   'index': 'VSTO',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'RecreationalProducts',
#   'volumechange': 2.4,
#   'sentimentchange': 0.06,
#   'wk52_high': '33.47',
#   'mkt_Cap_bill': '1.77b'},
#  {'Unnamed: 0': 0,
#   'index': 'VXX',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'InvestmentTrustsOrMutualFunds',
#   'volumechange': -14.29,
#   'sentimentchange': 0.48,
#   'wk52_high': '78.84',
#   'mkt_Cap_bill': '– – –'},
#  {'Unnamed: 0': 0,
#   'index': 'VZ',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'MajorTelecommunications',
#   'volumechange': 0.29,
#   'sentimentchange': -0.31,
#   'wk52_high': '61.9500',
#   'mkt_Cap_bill': '228.91b'},
#  {'Unnamed: 0': 0,
#   'index': 'WEN',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Restaurants',
#   'volumechange': -5.0,
#   'sentimentchange': -1.19,
#   'wk52_high': '24.9100',
#   'mkt_Cap_bill': '4.76b'},
#  {'Unnamed: 0': 0,
#   'index': 'WFC',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'MajorBanks',
#   'volumechange': -14.04,
#   'sentimentchange': 7.45,
#   'wk52_high': '48.4900',
#   'mkt_Cap_bill': '134.62b'},
#  {'Unnamed: 0': 0,
#   'index': 'WLL',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'OilAndGasProduction',
#   'volumechange': -3.39,
#   'sentimentchange': -1.0,
#   'wk52_high': '28.36',
#   'mkt_Cap_bill': '987.17m'},
#  {'Unnamed: 0': 0,
#   'index': 'WMT',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'FoodRetail',
#   'volumechange': -3.04,
#   'sentimentchange': 0.27,
#   'wk52_high': '153.6597',
#   'mkt_Cap_bill': '403.26b'},
#  {'Unnamed: 0': 0,
#   'index': 'WORK',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PackagedSoftware',
#   'volumechange': -3.13,
#   'sentimentchange': -0.83,
#   'wk52_high': '44.15',
#   'mkt_Cap_bill': '24.92b'},
#  {'Unnamed: 0': 0,
#   'index': 'X',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'Steel',
#   'volumechange': -9.6,
#   'sentimentchange': 0.77,
#   'wk52_high': '24.71',
#   'mkt_Cap_bill': '3.65b'},
#  {'Unnamed: 0': 0,
#   'index': 'XOM',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'IntegratedOil',
#   'volumechange': 5.73,
#   'sentimentchange': 1.12,
#   'wk52_high': '61.53',
#   'mkt_Cap_bill': '211.44b'},
#  {'Unnamed: 0': 0,
#   'index': 'Y',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PropertyOrCasualtyInsurance',
#   'volumechange': 0.0,
#   'sentimentchange': 0.0,
#   'wk52_high': '847.9450',
#   'mkt_Cap_bill': '8.60b'},
#  {'Unnamed: 0': 0,
#   'index': 'ZS',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PackagedSoftware',
#   'volumechange': 6.85,
#   'sentimentchange': 0.0,
#   'wk52_high': '224',
#   'mkt_Cap_bill': '29.09b'},
#  {'Unnamed: 0': 0,
#   'index': 'ZTS',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PharmaceuticalsGeneric',
#   'volumechange': -12.2,
#   'sentimentchange': 0.0,
#   'wk52_high': '176.64',
#   'mkt_Cap_bill': '75.70b'},
#  {'Unnamed: 0': 0,
#   'index': 'ZYNE',
#   'dateTime': '2021-02-05 21:00:00',
#   'industry': 'PharmaceuticalsOther',
#   'volumechange': 11.27,
#   'sentimentchange': 0.19,
#   'wk52_high': '7.45',
#   'mkt_Cap_bill': '149.55m'}]

# %%
pd.DataFrame(rows)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-da61d6de4944> in <module>
# ----> 1 pd.DataFrame(rows)
#
# NameError: name 'rows' is not defined
